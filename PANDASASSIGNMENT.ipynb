# %%
import pandas as pd
import numpy as np

# %% [markdown]
# QUESTION 1
# 1. Read superstore data

# %%
ssdf=pd.read_excel('Superstore.xls')
ssdf.head(10)
# Out:
#      no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0   NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1   2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2   3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3   4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4   5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5   6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6   7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7   8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8   9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9  10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# ...

# %% [markdown]
# 2. find the index of the data
# 3. find the columns of the data

# %%
ssdf.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
ssdf.columns
# Out:
# Index(['no', 'order_Id', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductID', 'Category', 'Sub-Category', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# 4. if columns name is having space then remove the
# space and rename the column. find the various ways
# to rename the column

# %%
ssdf.columns=ssdf.columns.str.replace(' ','')
ssdf.columns 
#2nd method
ssdf.columns=['no', 'order_Id', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
       'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
       'Region', 'ProductID', 'Category', 'Sub-Category', 'ProductName',
       'Sales', 'Quantity', 'Discount', 'Profit']

# %% [markdown]
# 5th. display first 40 records
# 6th. display last 15 records from the data

# %%
ssdf.head(40)
ssdf.tail(15)
# Out:
#           no        order_Id  OrderDate   ShipDate        ShipMode CustomerID  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class   AP-10720
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class   SW-20455
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class   TB-21055
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class   RC-19960
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class   RC-19960
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class   DV-13465
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class   DV-13465
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class   ML-17410
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class   RA-19885
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class   RA-19885
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class   TB-21400
# ...

# %% [markdown]
# 7. change the setting to display minimum 30 rows for
# given data

# %%
#pd.iter_rows()
#declaration of dynamic variables
#pd.resample

# %%
pd.options.display.min_rows=30
ssdf
# Out:
#           no        order_Id  OrderDate   ShipDate        ShipMode CustomerID  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class   CG-12520
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 6        7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 7        8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 8        9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 9       10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 10      11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# ...

# %% [markdown]
# Question 8
# 8. change the display setting to minimum row as 3

# %%
pd.options.display.min_rows=3
ssdf
# Out:
#           no        order_Id  OrderDate   ShipDate      ShipMode CustomerID  \
# 0        NaN             NaN 2016-11-08 2016-11-11  Second Class   CG-12520
# ...      ...             ...        ...        ...           ...        ...
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class   CC-12220
#
#       CustomerName   Segment        Country         City  ... PostalCode  \
# 0      Claire Gute  Consumer  United States    Henderson  ...      42420
# ...            ...       ...            ...          ...  ...        ...
# 9993  Chris Cortes  Consumer  United States  Westminster  ...      92683
#
#       Region        ProductID         Category Sub-Category  \
# 0      South  FUR-BO-10001798        Furniture    Bookcases
# ...      ...              ...              ...          ...
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             ProductName   Sales  Quantity  \
# ...

# %% [markdown]
# 9. take a slice from the dataframe  based on the
# columns city, state, region, profit columns

# %%
ssdf.loc[ : ,['City','State','Region','Profit']] 
#ssdf[['City','State','Region','Profit']](Alternative method)
# Out:
#              City       State Region   Profit
# 0       Henderson    Kentucky  South  41.9136
# ...           ...         ...    ...      ...
# 9993  Westminster  California   West  72.9480
#
# [9994 rows x 4 columns]

# %% [markdown]
# 10.
# Take a  slice based on data available at 1000 to
# 1500  position and columns  from 4 to 8

# %%
ssdf.iloc[1000:1501,4:9]
# Out:
#             ShipMode CustomerID   CustomerName      Segment        Country
# 1000  Standard Class   FM-14290   Frank Merwin  Home Office  United States
# ...              ...        ...            ...          ...            ...
# 1500  Standard Class   NG-18430  Nathan Gelder     Consumer  United States
#
# [501 rows x 5 columns]

# %% [markdown]
# 11.
# Rename the index starts from 1900 to end of
# the data

# %%
len(ssdf)
# Out:
# 9994

# %%
ssdf.index=[ i for i in range (1900 ,1900+len(ssdf))] 
# ssdf.index = range(1900, 1900 + len(ssdf)) (Alternative)
# ssdf.index = pd.RangeIndex(start=1900, stop=1900 + len(ssdf), step=1) (Alternative)
ssdf
# Out:
#            no        order_Id  OrderDate   ShipDate      ShipMode CustomerID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class   CG-12520
# ...       ...             ...        ...        ...           ...        ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class   CC-12220
#
#        CustomerName   Segment        Country         City  ... PostalCode  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...      42420
# ...             ...       ...            ...          ...  ...        ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...      92683
#
#        Region        ProductID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                              ProductName   Sales  Quantity  \
# ...

# %% [markdown]
# 12.
# Take a slice from data based on index having
# name as 1920 , 1940, 1945, 1980, and columns as
# profit, state, category, sub-category, region

# %%
ssdf.loc[[1920,1940,1945,1980],['Profit','State','Category','Sub-Category','Region']]
# Out:
#        Profit       State         Category Sub-Category   Region
# 1920   7.3840  California  Office Supplies      Binders     West
# 1940  41.7564       Texas       Technology       Phones  Central
# 1945   8.2062   Minnesota  Office Supplies      Binders  Central
# 1980   8.0352     Alabama  Office Supplies      Binders    South

# %% [markdown]
# 13. Check the data type of columns

# %%
ssdf.dtypes
# Out:
# no                     float64
# order_Id                object
# OrderDate       datetime64[ns]
# ShipDate        datetime64[ns]
# ShipMode                object
# CustomerID              object
# CustomerName            object
# Segment                 object
# Country                 object
# City                    object
# State                   object
# PostalCode               int64
# Region                  object
# ProductID               object
# Category                object
# Sub-Category            object
# ProductName             object
# Sales                  float64
# Quantity                 int64
# Discount               float64
# Profit                 float64
# dtype: object

# %% [markdown]
# 14. Find out the record for the month of jun-2014

# %%
ssdf[(ssdf['OrderDate']>='2014-06-01') & (ssdf['OrderDate']<'2014-07-01')]
# Out:
#            no        order_Id  OrderDate   ShipDate        ShipMode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11796  9897.0  CA-2014-156342 2014-06-17 2014-06-20    Second Class
#
#       CustomerID       CustomerName   Segment        Country         City  \
# 1905    BH-11710    Brosina Hoffman  Consumer  United States  Los Angeles
# ...          ...                ...       ...            ...          ...
# 11796   JF-15415  Jennifer Ferguson  Consumer  United States      Chicago
#
#        ... PostalCode   Region        ProductID         Category Sub-Category  \
# 1905   ...      90032     West  FUR-FU-10001487        Furniture  Furnishings
# ...    ...        ...      ...              ...              ...          ...
# 11796  ...      60653  Central  OFF-PA-10001725  Office Supplies        Paper
#
#                                              ProductName   Sales  Quantity  \
# ...

# %% [markdown]
# 15. Calculate month wise average of profit.

# %%
ssdf.resample(rule='m',on='OrderDate').mean(['Profit'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12868\2935572839.py:1: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   ssdf.resample(rule='m',on='OrderDate').mean(['Profit'])
#                      no    PostalCode       Sales  Quantity  Discount  \
# OrderDate
# 2014-01-31  4381.974684  54965.784810  180.213861  3.594937  0.126582
# 2014-02-28  5918.152174  66299.456522   98.258522  3.456522  0.176087
# 2014-03-31  5551.433121  52958.840764  354.719803  3.726115  0.167516
# 2014-04-30  5115.740741  57213.533333  209.595148  3.970370  0.110000
# 2014-05-31  5014.000000  53260.688525  193.838418  3.819672  0.155328
# 2014-06-30  3642.918519  50573.592593  256.260204  3.859259  0.172000
# 2014-07-31  5219.601399  63260.062937  237.387364  3.846154  0.171678
# 2014-08-31  4766.673203  56394.679739  182.414827  3.980392  0.131046
# 2014-09-30  4846.044776  54185.869403  305.139369  3.731343  0.159963
# ...

# %% [markdown]
# 16. Create the new data frame for California

# %%
california_df=ssdf[ssdf['State']=='California']
california_df
# Out:
#            no        order_id  OrderDate   ShipDate      ShipMode CustomerID  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16  Second Class   DV-13045
# ...       ...             ...        ...        ...           ...        ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class   CC-12220
#
#           CustomerName    Segment        Country         City  ... PostalCode  \
# 1902   Darrin Van Huff  Corporate  United States  Los Angeles  ...      90036
# ...                ...        ...            ...          ...  ...        ...
# 11893     Chris Cortes   Consumer  United States  Westminster  ...      92683
#
#        Region        ProductID         Category Sub-Category  \
# 1902     West  OFF-LA-10000240  Office Supplies       Labels
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                              ProductName   Sales  Quantity  \
# ...

# %%
ssdf[ssdf['State']=='california'] # checking for small c
# Out:
# Empty DataFrame
# Columns: [no, order_Id, OrderDate, ShipDate, ShipMode, CustomerID, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductID, Category, Sub-Category, ProductName, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# 17. Find sum of sales

# %%
sales_sum=ssdf['Sales'].sum()
sales_sum
# Out:
# np.float64(2297200.8603000003)

# %% [markdown]
# 18 Find state wise sum of sales.

# %%
df=ssdf.groupby('State')['Sales'].sum()
print(df)
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %% [markdown]
# 19. Find month wise sum  of sales

# %%
ssdf.resample(rule='m',on='OrderDate').sum(['Sales'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12868\2073875580.py:1: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   ssdf.resample(rule='m',on='OrderDate').sum(['Sales'])
#                    no  PostalCode        Sales  Quantity  Discount      Profit
# OrderDate
# 2014-01-31   346176.0     4342297   14236.8950       284     10.00   2450.1907
# 2014-02-28   272235.0     3049775    4519.8920       159      8.10    862.3084
# 2014-03-31   871575.0     8314538   55691.0090       585     26.30    498.7299
# 2014-04-30   690625.0     7723827   28295.3450       536     14.85   3488.8352
# 2014-05-31   611708.0     6497804   23648.2870       466     18.95   2738.7096
# 2014-06-30   491794.0     6827435   34595.1276       521     23.22   4976.5244
# 2014-07-31   746403.0     9046189   33946.3930       550     24.55   -841.4826
# 2014-08-31   729301.0     8628386   27909.4685       609     20.05   5318.1050
# ...

# %% [markdown]
# 20. Find country wise and city wise average profit

# %%
df1=ssdf.groupby(['Country','City'])['Profit'].mean()
df1.shape
df1  # only one country United States
# Out:
# Country        City
# United States  Aberdeen      6.630000
#                               ...
#                Yuma       -116.497725
# Name: Profit, Length: 531, dtype: float64

# %% [markdown]
# 21. Calculate region wise average profit.

# %%
ssdf.groupby('Region')['Profit'].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# 22. Find the ship mode which is more profitable.

# %%
profitable_ship=ssdf.groupby(['ShipMode'])['Profit'].sum().idxmax()  
print(' actual profit is:',profitable_ship)
# Out:
#  actual profit is: Standard Class

# %% [markdown]
# 23. Create a new data frame where loss is recorded

# %%
loss_df=ssdf[ssdf['Profit']<0]
loss_df
# Out:
#            no        order_id  OrderDate   ShipDate        ShipMode  \
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#       CustomerID      CustomerName      Segment        Country  \
# 1903    SO-20335    Sean O'Donnell     Consumer  United States
# ...          ...               ...          ...            ...
# 11862   CM-12655  Corinna Mitchell  Home Office  United States
#
#                   City  ... PostalCode   Region        ProductID   Category  \
# 1903   Fort Lauderdale  ...      33311    South  FUR-TA-10000577  Furniture
# ...                ...  ...        ...      ...              ...        ...
# 11862          Houston  ...      77041  Central  FUR-BO-10004218  Furniture
#
#       Sub-Category                                        ProductName  \
# ...

# %% [markdown]
# 24. Find category wise sub category wise sales

# %%
ssdf.groupby(['Category','Sub-Category'])['Sales'].sum()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       114879.9963
#                  Chairs          328449.1030
#                  Furnishings      91705.1640
#                  Tables          206965.5320
# Office Supplies  Appliances      107532.1610
#                  Art              27118.7920
#                  Binders         203412.7330
#                  Envelopes        16476.4020
#                  Fasteners         3024.2800
#                  Labels           12486.3120
#                  Paper            78479.2060
#                  Storage         223843.6080
#                  Supplies         46673.5380
# Technology       Accessories     167380.3180
#                  Copiers         149528.0300
#                  Machines        189238.6310
#                  Phones          330007.0540
# Name: Sales, dtype: float64

# %% [markdown]
# 25. Create a data frame for record where discount is 0

# %%
discount0_df=ssdf[ssdf['Discount']==0]
discount0_df
# Out:
#            no        order_id  OrderDate   ShipDate      ShipMode CustomerID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class   CG-12520
# ...       ...             ...        ...        ...           ...        ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class   CC-12220
#
#        CustomerName   Segment        Country         City  ... PostalCode  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...      42420
# ...             ...       ...            ...          ...  ...        ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...      92683
#
#        Region        ProductID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                              ProductName   Sales  Quantity  \
# ...

# %% [markdown]
# #verify 23,21

# %% [markdown]
# 26. Creata data frame where order date and ship date both are in JAN-2014

# %%
df1=ssdf[(ssdf['OrderDate']>='2014-01-1')&(ssdf['OrderDate']<'2014-02-1')&(ssdf['ShipDate']>='2014-01-1')&(ssdf['ShipDate']<'2014-02-1')]
df1.head(40)
# Out:
#           no        order_Id  OrderDate   ShipDate        ShipMode CustomerID  \
# 2492   593.0  CA-2014-135405 2014-01-09 2014-01-13  Standard Class   MS-17830
# 2493   594.0  CA-2014-135405 2014-01-09 2014-01-13  Standard Class   MS-17830
# 2616   717.0  CA-2014-130092 2014-01-11 2014-01-14     First Class   SV-20365
# 2639   740.0  CA-2014-112326 2014-01-04 2014-01-08  Standard Class   PO-19195
# 2640   741.0  CA-2014-112326 2014-01-04 2014-01-08  Standard Class   PO-19195
# 2641   742.0  CA-2014-112326 2014-01-04 2014-01-08  Standard Class   PO-19195
# 2663   764.0  CA-2014-162775 2014-01-13 2014-01-15    Second Class   CS-12250
# 2664   765.0  CA-2014-162775 2014-01-13 2014-01-15    Second Class   CS-12250
# 2665   766.0  CA-2014-162775 2014-01-13 2014-01-15    Second Class   CS-12250
# 2666   767.0  CA-2014-162775 2014-01-13 2014-01-15    Second Class   CS-12250
# 2667   768.0  CA-2014-162775 2014-01-13 2014-01-15    Second Class   CS-12250
# ...

# %% [markdown]
#  27. Find records having profit for consumer segment.

# %%
ssdf[(ssdf['Segment']=='Consumer')& (ssdf['Profit']>0)]
# Out:
#            no        order_Id  OrderDate   ShipDate      ShipMode CustomerID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class   CG-12520
# ...       ...             ...        ...        ...           ...        ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class   CC-12220
#
#        CustomerName   Segment        Country         City  ... Region  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...  South
# ...             ...       ...            ...          ...  ...    ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...   West
#
#              ProductID         Category Sub-Category  \
# 1900   FUR-BO-10001798        Furniture    Bookcases
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                              ProductName   Sales Quantity  \
# 1900                   Bush Somerset Collection Bookcase  261.96        2
# ...

# %% [markdown]
# Generate new data frame for every state (hint: dynamic variable creation)

# %%
for i in ssdf['State'].unique():
    globals()[f'df_{i}']=ssdf[ssdf['State']==i]
   
df_Alabama.head()
# Out:
#           no        order_Id  OrderDate   ShipDate        ShipMode CustomerID  \
# 1979    80.0  CA-2016-127208 2016-06-12 2016-06-15     First Class   SC-20770
# 1980    81.0  CA-2016-127208 2016-06-12 2016-06-15     First Class   SC-20770
# 2433   534.0  CA-2016-168753 2016-05-29 2016-06-01    Second Class   RL-19615
# 2434   535.0  CA-2016-168753 2016-05-29 2016-06-01    Second Class   RL-19615
# 3169  1270.0  CA-2017-100426 2017-06-04 2017-06-08  Standard Class   DC-12850
#
#             CustomerName    Segment        Country        City  ... Region  \
# 1979  Stewart Carmichael  Corporate  United States     Decatur  ...  South
# 1980  Stewart Carmichael  Corporate  United States     Decatur  ...  South
# 2433           Rob Lucas   Consumer  United States  Montgomery  ...  South
# 2434           Rob Lucas   Consumer  United States  Montgomery  ...  South
# 3169        Dan Campbell   Consumer  United States    Florence  ...  South
#
# ...

# %% [markdown]
# 29. Generate the region wise, state wise average profit and sales and then extract information for east region.

# %%
df=ssdf.groupby(['Region','State',])[['Sales','Profit']].mean() 

df.reset_index(inplace=True)
r_df=df[df['Region']=='East']
r_df
# Out:
#    Region                 State       Sales      Profit
# 13   East           Connecticut  163.223866   42.823071
# 14   East              Delaware  285.948635  103.930988
# 15   East  District of Columbia  286.502000  105.958930
# 16   East                 Maine  158.816250   56.810775
# 17   East              Maryland  225.766886   66.963608
# 18   East         Massachusetts  212.106919   50.262975
# 19   East         New Hampshire  270.093481   63.203807
# 20   East            New Jersey  275.110092   75.176260
# 21   East              New York  275.599531   65.637011
# 22   East                  Ohio  166.861697  -36.186304
# 23   East          Pennsylvania  198.487077  -26.507598
# 24   East          Rhode Island  404.070643  130.100523
# 25   East               Vermont  811.760909  204.088936
# 26   East         West Virginia  302.456000   46.480400

# %% [markdown]
# 30. Find all record for furniture delivered in Texas

# %%
ssdf[(ssdf['Category']=='Furniture')& (ssdf['State']=='Texas')]
# Out:
#            no        order_Id  OrderDate   ShipDate     ShipMode CustomerID  \
# 1936     37.0  CA-2016-117590 2016-12-08 2016-12-10  First Class   GH-14485
# ...       ...             ...        ...        ...          ...        ...
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22  First Class   CM-12655
#
#            CustomerName      Segment        Country        City  ...   Region  \
# 1936          Gene Hale    Corporate  United States  Richardson  ...  Central
# ...                 ...          ...            ...         ...  ...      ...
# 11862  Corinna Mitchell  Home Office  United States     Houston  ...  Central
#
#              ProductID   Category Sub-Category  \
# 1936   FUR-FU-10003664  Furniture  Furnishings
# ...                ...        ...          ...
# 11862  FUR-BO-10004218  Furniture    Bookcases
#
#                                              ProductName     Sales Quantity  \
# ...
